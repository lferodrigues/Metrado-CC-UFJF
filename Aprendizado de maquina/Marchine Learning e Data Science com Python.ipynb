# %% [markdown]
# **Marchine Learning e Data Science com Python**

# %% [markdown]
# Importação das bibliotecas básicas

# %%
pip install plotly --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 70.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %% [markdown]
# Plotly é uma biblioteca que gera graficos avançados

# %%
import pandas as pd
'Biblioteca que libera o uso de arquivo CSV'
import numpy as np
'Biblioteca matematica do python'
import seaborn as sns
'Biblioteca para visualização de graficos'
import matplotlib.pyplot as plt
'Biblioteca para visualização de graficos'
import plotly.express as px

# %% [markdown]
# **Base de dados de credito**
#
#
# Fonte: https://www.kaggle.com/laotse/credit-risk-dataset

# %% [markdown]
# **Criando variaveis de dados**

# %%
base_credit = pd.read_csv('/content/credit_data.csv')

# %% [markdown]
# **Visualizando os registros**

# %%
base_credit
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %% [markdown]
# **Visualizando os primeiros registros**

# %%
base_credit.head(10) #.head mostra os cabeçalho por padrao ele mostra os 5
#caso queira modificar apenas insira a quantidade dentro dos parenteses.
# Out:
#    clientid        income        age         loan  default
# 0         1  66155.925095  59.017015  8106.532131        0
# 1         2  34415.153966  48.117153  6564.745018        0
# 2         3  57317.170063  63.108049  8020.953296        0
# 3         4  42709.534201  45.751972  6103.642260        0
# 4         5  66952.688845  18.584336  8770.099235        1
# 5         6  24904.064140  57.471607    15.498598        0
# 6         7  48430.359613  26.809132  5722.581981        0
# 7         8  24500.141984  32.897548  2971.003310        1
# 8         9  40654.892537  55.496853  4755.825280        0
# 9        10  25075.872771  39.776378  1409.230371        0

# %% [markdown]
# **Visualizando os ultimos registros**

# %%
base_credit.tail()
# Out:
#       clientid        income        age         loan  default
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0

# %% [markdown]
# **Visualizando modo estatistico**

# %%
base_credit.describe()#metodo describe e um metodo do panda
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %% [markdown]
# **Visualizando os dados**

# %%
# fazendo uma contagem de quantos registros existente em cada classe
np.unique(base_credit['default'],return_counts=True)
# Out:
# (array([0, 1]), array([1717,  283]))

# %%
#Essa função faz uma contagem de quantos registros tem  e gera um grafico

sns.countplot(x = base_credit['default'])
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
plt.hist(x = base_credit['age'])
# Out:
# (array([  1.,   1.,   1.,   0.,   0.,   0., 499., 467., 514., 514.]),
#  array([-52.42327992, -40.78377234, -29.14426477, -17.50475719,
#          -5.86524962,   5.77425796,  17.41376554,  29.05327311,
#          40.69278069,  52.33228827,  63.97179584]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = base_credit['income'])
# Out:
# (array([189., 198., 199., 179., 204., 209., 206., 199., 219., 198.]),
#  array([20014.48947005, 25012.60908088, 30010.7286917 , 35008.84830253,
#         40006.96791336, 45005.08752419, 50003.20713501, 55001.32674584,
#         59999.44635667, 64997.5659675 , 69995.68557832]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = base_credit['loan'] )
# Out:
# (array([345., 373., 318., 277., 266., 171., 104.,  89.,  40.,  17.]),
#  array([1.37762959e+00, 1.37784499e+03, 2.75431235e+03, 4.13077971e+03,
#         5.50724707e+03, 6.88371443e+03, 8.26018180e+03, 9.63664916e+03,
#         1.10131165e+04, 1.23895839e+04, 1.37660512e+04]),
#  <BarContainer object of 10 artists>)

# %%
grafico = px.scatter_matrix(base_credit,dimensions=['age'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
